# %%
import pandas as pd

# %%
df = pd.read_excel('Attribute DataSet.xlsx')

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel(r'Attribute DataSetEdited.xlsx', sheet_name = 'rulu', header = None, names = ['A', 'B', 'C', 'D'])
# Out:
#        A    B     C      D
# 0  sddfd  fsg  sgdf  sdhfd
# 1     sg  aad   NaN    NaN
# 2    sdf  NaN   NaN    NaN
# 3     sg   sg    sh     sg
# 4   styr   sg   NaN    NaN
# 5     sg  NaN  ryrg    NaN
# 6     sg   sg   NaN    NaN

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
pd.read_csv('haberman.csv', header = None, names = ['Age', 'No of patient\'s', 'No of Positive', 'Survival'])
# Out:
#      Age  No of patient's  No of Positive  Survival
# 0     30               64               1         1
# 1     30               62               3         1
# 2     30               65               0         1
# 3     31               59               2         1
# 4     31               65               4         1
# ..   ...              ...             ...       ...
# 301   75               62               1         1
# 302   76               67               0         1
# 303   77               65               3         1
# 304   78               65               1         2
# 305   83               58               2         2
#
# [306 rows x 4 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# ...    ...    ...    ...    ...    ...    ...      ...    ...       ...
# 1245  2005  0.422  0.252 -0.024 -0.584 -0.285  1.88850  0.043        Up
# 1246  2005  0.043  0.422  0.252 -0.024 -0.584  1.28581 -0.955      Down
# 1247  2005 -0.955  0.043  0.422  0.252 -0.024  1.54047  0.130        Up
# 1248  2005  0.130 -0.955  0.043  0.422  0.252  1.42236 -0.298      Down
# 1249  2005 -0.298  0.130 -0.955  0.043  0.422  1.38254 -0.489      Down
#
# [1250 rows x 9 columns]

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BCF.csv')
# Out:
#            date  values.I2P  values.P2I  values.JPI
# 0    1996-04-01   -2.580556   -0.836444        63.3
# 1    1996-05-01   -2.882258   -1.972581        66.3
# 2    1996-06-01   -1.742778   -0.478778        59.7
# 3    1996-07-01   -0.397796   -1.574301        63.3
# 4    1996-08-01   -0.977151   -1.797312        63.8
# ..          ...         ...         ...         ...
# 112  2005-08-01   -2.144935   -1.646989        49.0
# 113  2005-09-01   -3.543270   -1.769889        49.9
# 114  2005-10-01   -4.500484   -2.309946        50.6
# 115  2005-11-01   -4.098556   -1.528611        57.4
# 116  2005-12-01   -5.797043   -2.872849        52.9
#
# [117 rows x 4 columns]

# %%
a = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
js = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'rhkarls', 'id': 2330659, 'node_id':...
# 1     {'login': 'SandroCasagrande', 'id': 22665904, ...
# 2     {'login': 'VHElise', 'id': 1756220, 'node_id':...
# 3     {'login': 'rzpan', 'id': 29119979, 'node_id': ...
# 4     {'login': 'JeffersonQin', 'id': 30655701, 'nod...
# 5     {'login': 'daviewales', 'id': 2499066, 'node_i...
# 6     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 7     {'login': 'james-d-f', 'id': 22453728, 'node_i...
# 8     {'login': 'BeRT2me', 'id': 54292304, 'node_id'...
# 9     {'login': 'bbizarro', 'id': 9373954, 'node_id'...
# 10    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 11    {'login': 'skrawcz', 'id': 2328071, 'node_id':...
# 12    {'login': 'attack68', 'id': 24256554, 'node_id...
# 13    {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 14    {'login': 'Codeberg-AsGithubAlternative-buhtz'...
# 15    {'login': 'dannyi96', 'id': 15380498, 'node_id...
# 16    {'login': 'weikhor', 'id': 36619387, 'node_id'...
# ...

# %%
js['user'][0]
# Out:
# {'login': 'rhkarls',
#  'id': 2330659,
#  'node_id': 'MDQ6VXNlcjIzMzA2NTk=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/2330659?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/rhkarls',
#  'html_url': 'https://github.com/rhkarls',
#  'followers_url': 'https://api.github.com/users/rhkarls/followers',
#  'following_url': 'https://api.github.com/users/rhkarls/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/rhkarls/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/rhkarls/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/rhkarls/subscriptions',
#  'organizations_url': 'https://api.github.com/users/rhkarls/orgs',
#  'repos_url': 'https://api.github.com/users/rhkarls/repos',
#  'events_url': 'https://api.github.com/users/rhkarls/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/rhkarls/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_json('test1234.json')

# %%
pwd
# Out:
# 'C:\\Users\\atsuy'

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_csv("D://Attritest123.csv")

# %%
pwd
# Out:
# 'C:\\Users\\atsuy'

# %%
"""Mysql :
    1. create a table for attribute datset and dress dataset.
    2. Do a bulk load for theses two table for respective dataset.
    3. Read these dataset in pandas as a dataframe
    4. COnvert attribute dataset ub json format.
    5. Store these dataset into mongodDB.
    6. In sql task try to perform left join operation with attribute dataset and dress dataset in column Dress_ID.
    7. Write a sql query to find out how many unique dress that we have based on dress ID.
    8. Try to find out how many dress is having recommendation 0.
    9. Try to find out tatal dress sale for individual dress ID.
    10. Try to find out the third highest most selling dress ID.
    """

# %%
df1 = pd.read_excel(r'Dress Sales.xlsx')

# %%
df1
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# ...

# %%
df1.to_csv("D://dresssales.csv")
